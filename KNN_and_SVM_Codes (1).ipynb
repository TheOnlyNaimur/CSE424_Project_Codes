# %%
#KNN Code
import pandas as pd

# Load the dataset to examine its structure
file_path = '/content/cleaned_earthquakes_2023_global.csv'
data = pd.read_csv(file_path)

data.info(), data.head()
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd

# Load dataset
data = pd.read_csv('/content/cleaned_earthquakes_2023_global.csv')

# Feature selection
features = data[['latitude', 'longitude', 'depth', 'mag', 'gap', 'dmin', 'rms']]
target = data['mag_category'].astype('category')
target_encoded = target.cat.codes

# Splitting dataset
X_train, X_test, y_train, y_test = train_test_split(features, target_encoded, test_size=0.3, random_state=42)

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# KNN Model
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, y_train)
knn_predictions = knn.predict(X_test_scaled)

# Evaluation
knn_accuracy = accuracy_score(y_test, knn_predictions)
print(f"KNN Accuracy: {knn_accuracy}")
print("KNN Classification Report:")
print(classification_report(y_test, knn_predictions, target_names=target.cat.categories))


#SVM Code
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import classification_report, accuracy_score
import pandas as pd

# Load dataset
data = pd.read_csv('/content/cleaned_earthquakes_2023_global.csv')

# Feature selection
features = data[['latitude', 'longitude', 'depth', 'mag', 'gap', 'dmin', 'rms']]
target = data['mag_category'].astype('category')
target_encoded = target.cat.codes

# Splitting dataset
X_train, X_test, y_train, y_test = train_test_split(features, target_encoded, test_size=0.3, random_state=42)

# Scaling features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# SVM Model
svm = SVC(kernel='rbf', random_state=42)
svm.fit(X_train_scaled, y_train)
svm_predictions = svm.predict(X_test_scaled)

# Evaluation
svm_accuracy = accuracy_score(y_test, svm_predictions)
print(f"SVM Accuracy: {svm_accuracy}")
print("SVM Classification Report:")
print(classification_report(y_test, svm_predictions, target_names=target.cat.categories))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22913 entries, 0 to 22912
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             22913 non-null  object
#  1   latitude         22913 non-null  float64
#  2   longitude        22913 non-null  float64
#  3   depth            22913 non-null  float64
#  4   mag              22913 non-null  float64
#  5   magType          22913 non-null  object
#  6   nst              22913 non-null  int64
#  7   gap              22913 non-null  float64
#  8   dmin             22913 non-null  float64
#  9   rms              22913 non-null  float64
#  10  net              22913 non-null  object
#  11  id               22913 non-null  object
#  12  updated          22913 non-null  object
#  13  place            21505 non-null  object
#  14  type             22913 non-null  object
#  15  horizontalError  22913 non-null  float64
# ...
